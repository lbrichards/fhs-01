# %% [markdown]
# <a href="https://colab.research.google.com/github/lbrichards/fhs-01/blob/master/FHS_SEP_26_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ２０１９年９月２６日　パイソン講座

# %% [markdown]
# ## 乱数

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
import numpy
X = numpy.random.normal(size=1000, loc=.1)
Y = X.cumsum()
plt.plot(Y)

# %%
plt.hist(X)
# Out:
# (array([  8.,  32.,  80., 175., 253., 237., 135.,  60.,  17.,   3.]),
#  array([-2.93543536, -2.31181321, -1.68819106, -1.0645689 , -0.44094675,
#          0.1826754 ,  0.80629756,  1.42991971,  2.05354187,  2.67716402,
#          3.30078617]),
#  <a list of 10 Patch objects>)
